# %% [markdown]
# ## Test the discrimination fitting with idealized examples
#
# Examples: d=1, rest as before, now fitting with that freedom.

# %%
from utils import create_data, model_and_visualize, grade_df

# %%
data = create_data()
df = grade_df(data)
# df.tail(20)

# %%
model_and_visualize(df)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Course difficulty, Course sensitivity, Student ability, eps]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 15:24<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 2_000 tune and 1_000 draw iterations (8_000 + 4_000 draws total) took 925 seconds.
# (Inference data with groups:
#  	> posterior
#  	> log_likelihood
#  	> sample_stats
#  	> observed_data,
# ...
